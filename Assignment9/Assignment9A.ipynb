# %% [markdown]
# <a href="https://colab.research.google.com/github/Curiousss/EVA/blob/master/Assignment9/Assignment9A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
print(train_features[0].shape)
print(num_classes)
# Out:
# (32, 32, 3)
# 10

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
from keras.layers import GlobalMaxPooling2D
# Define the model
# RF 3
# input size 32
model = Sequential()
model.add(Convolution2D(64, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

#RF 5
# input size 32
model.add(Convolution2D(128, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

#RF 10
# input size 32
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(64, 1, 1, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

#RF 12
# input size 16
model.add(Convolution2D(128, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# RF 14
# input size 16
model.add(Convolution2D(256, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

#RF 28
# input size 16
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(128, 1, 1, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

#RF 30
# input size 8
model.add(Convolution2D(256, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

#RF 32
# input size 8
model.add(Convolution2D(num_classes, 8, 8))
#model.add(Flatten())
model.add(GlobalMaxPooling2D())
model.add(Activation('softmax'))

model.summary()

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0629 12:39:38.708728 140520737036160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# W0629 12:39:38.747547 140520737036160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0629 12:39:38.755187 140520737036160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0629 12:39:38.792056 140520737036160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0629 12:39:38.794793 140520737036160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0629 12:39:41.750703 140520737036160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0629 12:39:41.904996 140520737036160 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
#   del sys.path[0]
# W0629 12:39:42.014850 140520737036160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (1, 1), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:43: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:50: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:57: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8))`
# W0629 12:39:42.515717 140520737036160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        8256
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# activation_5 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         32896
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 1, 1, 10)          163850
# _________________________________________________________________
# global_max_pooling2d_1 (Glob (None, 10)                0
# _________________________________________________________________
# activation_8 (Activation)    (None, 10)                0
# =================================================================
# Total params: 948,938
# Trainable params: 946,890
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, ModelCheckpoint

checkpoint = ModelCheckpoint('modelBest.h5', verbose=1, monitor='val_acc',save_best_only=True, mode='auto')

datagen = ImageDataGenerator(zoom_range=0.1, 
                             horizontal_flip=True,
                            featurewise_center=True,
                            featurewise_std_normalization=True)
datagen.fit(train_features)
testgen = ImageDataGenerator(featurewise_center=True,
                            featurewise_std_normalization=True)
testgen.fit(test_features)

# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = testgen.flow(test_features, test_labels), validation_steps=100, verbose=1,
                                callbacks=[checkpoint])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=<keras_pre..., validation_steps=100, verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
# W0627 14:05:03.278038 139976504383360 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 390/390 [==============================] - 58s 149ms/step - loss: 1.9709 - acc: 0.4397 - val_loss: 1.7600 - val_acc: 0.5000
#
# Epoch 00001: val_acc improved from -inf to 0.50000, saving model to modelBest.h5
# Epoch 2/100
# 390/390 [==============================] - 54s 138ms/step - loss: 1.4362 - acc: 0.5562 - val_loss: 1.4318 - val_acc: 0.5731
#
# Epoch 00002: val_acc improved from 0.50000 to 0.57312, saving model to modelBest.h5
# Epoch 3/100
# 390/390 [==============================] - 54s 137ms/step - loss: 1.1628 - acc: 0.6368 - val_loss: 1.4688 - val_acc: 0.6025
#
# Epoch 00003: val_acc improved from 0.57312 to 0.60250, saving model to modelBest.h5
# Epoch 4/100
# 390/390 [==============================] - 54s 137ms/step - loss: 1.3736 - acc: 0.6093 - val_loss: 1.1391 - val_acc: 0.6401
#
# Epoch 00004: val_acc improved from 0.60250 to 0.64008, saving model to modelBest.h5
# Epoch 5/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.9683 - acc: 0.6776 - val_loss: 1.0363 - val_acc: 0.6928
#
# Epoch 00005: val_acc improved from 0.64008 to 0.69281, saving model to modelBest.h5
# Epoch 6/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.7760 - acc: 0.7298 - val_loss: 1.6710 - val_acc: 0.6928
#
# Epoch 00006: val_acc did not improve from 0.69281
# Epoch 7/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.7054 - acc: 0.7552 - val_loss: 1.0722 - val_acc: 0.7202
#
# Epoch 00007: val_acc improved from 0.69281 to 0.72016, saving model to modelBest.h5
# Epoch 8/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.6465 - acc: 0.7753 - val_loss: 1.2211 - val_acc: 0.7356
#
# Epoch 00008: val_acc improved from 0.72016 to 0.73562, saving model to modelBest.h5
# Epoch 9/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.6371 - acc: 0.7785 - val_loss: 0.6997 - val_acc: 0.7688
#
# Epoch 00009: val_acc improved from 0.73562 to 0.76875, saving model to modelBest.h5
# Epoch 10/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.5840 - acc: 0.7961 - val_loss: 0.7495 - val_acc: 0.7550
#
# Epoch 00010: val_acc did not improve from 0.76875
# Epoch 11/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.5634 - acc: 0.8040 - val_loss: 0.6291 - val_acc: 0.7881
#
# Epoch 00011: val_acc improved from 0.76875 to 0.78812, saving model to modelBest.h5
# Epoch 12/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.5370 - acc: 0.8109 - val_loss: 0.6013 - val_acc: 0.7987
#
# Epoch 00012: val_acc improved from 0.78812 to 0.79875, saving model to modelBest.h5
# Epoch 13/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.5103 - acc: 0.8227 - val_loss: 0.6021 - val_acc: 0.8028
#
# Epoch 00013: val_acc improved from 0.79875 to 0.80276, saving model to modelBest.h5
# Epoch 14/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.4927 - acc: 0.8278 - val_loss: 0.6171 - val_acc: 0.7997
#
# Epoch 00014: val_acc did not improve from 0.80276
# Epoch 15/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.4882 - acc: 0.8300 - val_loss: 0.5754 - val_acc: 0.8116
#
# Epoch 00015: val_acc improved from 0.80276 to 0.81156, saving model to modelBest.h5
# Epoch 16/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.4547 - acc: 0.8417 - val_loss: 0.5811 - val_acc: 0.8103
#
# Epoch 00016: val_acc did not improve from 0.81156
# Epoch 17/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.4328 - acc: 0.8475 - val_loss: 0.5786 - val_acc: 0.8119
#
# Epoch 00017: val_acc improved from 0.81156 to 0.81188, saving model to modelBest.h5
# Epoch 18/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.4265 - acc: 0.8492 - val_loss: 0.5514 - val_acc: 0.8219
#
# Epoch 00018: val_acc improved from 0.81188 to 0.82188, saving model to modelBest.h5
# Epoch 19/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.4090 - acc: 0.8561 - val_loss: 0.5612 - val_acc: 0.8222
#
# Epoch 00019: val_acc improved from 0.82188 to 0.82224, saving model to modelBest.h5
# Epoch 20/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.4035 - acc: 0.8580 - val_loss: 0.5513 - val_acc: 0.8237
#
# Epoch 00020: val_acc improved from 0.82224 to 0.82375, saving model to modelBest.h5
# Epoch 21/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.3868 - acc: 0.8634 - val_loss: 0.6049 - val_acc: 0.8063
#
# Epoch 00021: val_acc did not improve from 0.82375
# Epoch 22/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.3774 - acc: 0.8675 - val_loss: 0.5025 - val_acc: 0.8219
#
# Epoch 00022: val_acc did not improve from 0.82375
# Epoch 23/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.3984 - acc: 0.8611 - val_loss: 0.5475 - val_acc: 0.8222
#
# Epoch 00023: val_acc did not improve from 0.82375
# Epoch 24/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.3631 - acc: 0.8725 - val_loss: 0.5376 - val_acc: 0.8281
#
# Epoch 00024: val_acc improved from 0.82375 to 0.82812, saving model to modelBest.h5
# Epoch 25/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.3363 - acc: 0.8803 - val_loss: 0.4769 - val_acc: 0.8438
#
# Epoch 00025: val_acc improved from 0.82812 to 0.84375, saving model to modelBest.h5
# Epoch 26/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.3346 - acc: 0.8806 - val_loss: 0.4768 - val_acc: 0.8445
#
# Epoch 00026: val_acc improved from 0.84375 to 0.84454, saving model to modelBest.h5
# Epoch 27/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.3347 - acc: 0.8820 - val_loss: 0.5789 - val_acc: 0.8178
#
# Epoch 00027: val_acc did not improve from 0.84454
# Epoch 28/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.3115 - acc: 0.8900 - val_loss: 0.4804 - val_acc: 0.8444
#
# Epoch 00028: val_acc did not improve from 0.84454
# Epoch 29/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.3100 - acc: 0.8911 - val_loss: 0.4430 - val_acc: 0.8543
#
# Epoch 00029: val_acc improved from 0.84454 to 0.85427, saving model to modelBest.h5
# Epoch 30/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.3067 - acc: 0.8912 - val_loss: 0.4912 - val_acc: 0.8359
#
# Epoch 00030: val_acc did not improve from 0.85427
# Epoch 31/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2942 - acc: 0.8958 - val_loss: 0.4687 - val_acc: 0.8500
#
# Epoch 00031: val_acc did not improve from 0.85427
# Epoch 32/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2898 - acc: 0.8954 - val_loss: 0.5565 - val_acc: 0.8204
#
# Epoch 00032: val_acc did not improve from 0.85427
# Epoch 33/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2787 - acc: 0.9014 - val_loss: 0.4768 - val_acc: 0.8472
#
# Epoch 00033: val_acc did not improve from 0.85427
# Epoch 34/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2701 - acc: 0.9043 - val_loss: 0.5190 - val_acc: 0.8419
#
# Epoch 00034: val_acc did not improve from 0.85427
# Epoch 35/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2685 - acc: 0.9027 - val_loss: 0.4854 - val_acc: 0.8464
#
# Epoch 00035: val_acc did not improve from 0.85427
# Epoch 36/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2605 - acc: 0.9072 - val_loss: 0.4626 - val_acc: 0.8478
#
# Epoch 00036: val_acc did not improve from 0.85427
# Epoch 37/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2577 - acc: 0.9081 - val_loss: 0.4486 - val_acc: 0.8566
#
# Epoch 00037: val_acc improved from 0.85427 to 0.85656, saving model to modelBest.h5
# Epoch 38/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2487 - acc: 0.9107 - val_loss: 0.4296 - val_acc: 0.8643
#
# Epoch 00038: val_acc improved from 0.85656 to 0.86432, saving model to modelBest.h5
# Epoch 39/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.2435 - acc: 0.9127 - val_loss: 0.4890 - val_acc: 0.8409
#
# Epoch 00039: val_acc did not improve from 0.86432
# Epoch 40/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2391 - acc: 0.9154 - val_loss: 0.4484 - val_acc: 0.8606
#
# Epoch 00040: val_acc did not improve from 0.86432
# Epoch 41/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2353 - acc: 0.9155 - val_loss: 0.4859 - val_acc: 0.8470
#
# Epoch 00041: val_acc did not improve from 0.86432
# Epoch 42/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2320 - acc: 0.9173 - val_loss: 0.4948 - val_acc: 0.8516
#
# Epoch 00042: val_acc did not improve from 0.86432
# Epoch 43/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2294 - acc: 0.9197 - val_loss: 0.4609 - val_acc: 0.8538
#
# Epoch 00043: val_acc did not improve from 0.86432
# Epoch 44/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.2185 - acc: 0.9225 - val_loss: 0.4234 - val_acc: 0.8653
#
# Epoch 00044: val_acc improved from 0.86432 to 0.86526, saving model to modelBest.h5
# Epoch 45/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2164 - acc: 0.9227 - val_loss: 0.5079 - val_acc: 0.8622
#
# Epoch 00045: val_acc did not improve from 0.86526
# Epoch 46/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.2252 - acc: 0.9199 - val_loss: 0.4413 - val_acc: 0.8681
#
# Epoch 00046: val_acc improved from 0.86526 to 0.86813, saving model to modelBest.h5
# Epoch 47/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.2156 - acc: 0.9226 - val_loss: 0.4578 - val_acc: 0.8562
#
# Epoch 00047: val_acc did not improve from 0.86813
# Epoch 48/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2244 - acc: 0.9206 - val_loss: 0.5141 - val_acc: 0.8525
#
# Epoch 00048: val_acc did not improve from 0.86813
# Epoch 49/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2371 - acc: 0.9155 - val_loss: 0.4987 - val_acc: 0.8491
#
# Epoch 00049: val_acc did not improve from 0.86813
# Epoch 50/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.2005 - acc: 0.9284 - val_loss: 0.4371 - val_acc: 0.8672
#
# Epoch 00050: val_acc did not improve from 0.86813
# Epoch 51/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1983 - acc: 0.9287 - val_loss: 0.4287 - val_acc: 0.8753
#
# Epoch 00051: val_acc improved from 0.86813 to 0.87531, saving model to modelBest.h5
# Epoch 52/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.1941 - acc: 0.9315 - val_loss: 0.4170 - val_acc: 0.8738
#
# Epoch 00052: val_acc did not improve from 0.87531
# Epoch 53/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1955 - acc: 0.9293 - val_loss: 0.4644 - val_acc: 0.8562
#
# Epoch 00053: val_acc did not improve from 0.87531
# Epoch 54/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.1884 - acc: 0.9321 - val_loss: 0.4686 - val_acc: 0.8596
#
# Epoch 00054: val_acc did not improve from 0.87531
# Epoch 55/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1842 - acc: 0.9334 - val_loss: 0.4683 - val_acc: 0.8594
#
# Epoch 00055: val_acc did not improve from 0.87531
# Epoch 56/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1811 - acc: 0.9351 - val_loss: 0.4360 - val_acc: 0.8716
#
# Epoch 00056: val_acc did not improve from 0.87531
# Epoch 57/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.1874 - acc: 0.9328 - val_loss: 0.4621 - val_acc: 0.8671
#
# Epoch 00057: val_acc did not improve from 0.87531
# Epoch 58/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1756 - acc: 0.9361 - val_loss: 0.4298 - val_acc: 0.8628
#
# Epoch 00058: val_acc did not improve from 0.87531
# Epoch 59/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1786 - acc: 0.9363 - val_loss: 0.4399 - val_acc: 0.8716
#
# Epoch 00059: val_acc did not improve from 0.87531
# Epoch 60/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1699 - acc: 0.9390 - val_loss: 0.4574 - val_acc: 0.8687
#
# Epoch 00060: val_acc did not improve from 0.87531
# Epoch 61/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1753 - acc: 0.9375 - val_loss: 0.4497 - val_acc: 0.8625
#
# Epoch 00061: val_acc did not improve from 0.87531
# Epoch 62/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1696 - acc: 0.9384 - val_loss: 0.4079 - val_acc: 0.8781
#
# Epoch 00062: val_acc improved from 0.87531 to 0.87813, saving model to modelBest.h5
# Epoch 63/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1670 - acc: 0.9401 - val_loss: 0.4633 - val_acc: 0.8681
#
# Epoch 00063: val_acc did not improve from 0.87813
# Epoch 64/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.1654 - acc: 0.9421 - val_loss: 0.4475 - val_acc: 0.8728
#
# Epoch 00064: val_acc did not improve from 0.87813
# Epoch 65/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1653 - acc: 0.9405 - val_loss: 0.4849 - val_acc: 0.8641
#
# Epoch 00065: val_acc did not improve from 0.87813
# Epoch 66/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1638 - acc: 0.9424 - val_loss: 0.5785 - val_acc: 0.8514
#
# Epoch 00066: val_acc did not improve from 0.87813
# Epoch 67/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1608 - acc: 0.9434 - val_loss: 0.4704 - val_acc: 0.8631
#
# Epoch 00067: val_acc did not improve from 0.87813
# Epoch 68/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1619 - acc: 0.9424 - val_loss: 0.4771 - val_acc: 0.8656
#
# Epoch 00068: val_acc did not improve from 0.87813
# Epoch 69/100
# 390/390 [==============================] - 53s 136ms/step - loss: 0.1516 - acc: 0.9453 - val_loss: 0.4552 - val_acc: 0.8719
#
# Epoch 00069: val_acc did not improve from 0.87813
# Epoch 70/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1566 - acc: 0.9433 - val_loss: 0.4729 - val_acc: 0.8712
#
# Epoch 00070: val_acc did not improve from 0.87813
# Epoch 71/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1616 - acc: 0.9422 - val_loss: 0.4169 - val_acc: 0.8775
#
# Epoch 00071: val_acc did not improve from 0.87813
# Epoch 72/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1572 - acc: 0.9434 - val_loss: 0.4749 - val_acc: 0.8618
#
# Epoch 00072: val_acc did not improve from 0.87813
# Epoch 73/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.1502 - acc: 0.9463 - val_loss: 0.4427 - val_acc: 0.8759
#
# Epoch 00073: val_acc did not improve from 0.87813
# Epoch 74/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1425 - acc: 0.9482 - val_loss: 0.4347 - val_acc: 0.8712
#
# Epoch 00074: val_acc did not improve from 0.87813
# Epoch 75/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1524 - acc: 0.9455 - val_loss: 0.4996 - val_acc: 0.8625
#
# Epoch 00075: val_acc did not improve from 0.87813
# Epoch 76/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1472 - acc: 0.9463 - val_loss: 0.4431 - val_acc: 0.8747
#
# Epoch 00076: val_acc did not improve from 0.87813
# Epoch 77/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1402 - acc: 0.9503 - val_loss: 0.4079 - val_acc: 0.8800
#
# Epoch 00077: val_acc improved from 0.87813 to 0.88000, saving model to modelBest.h5
# Epoch 78/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1391 - acc: 0.9503 - val_loss: 0.4629 - val_acc: 0.8694
#
# Epoch 00078: val_acc did not improve from 0.88000
# Epoch 79/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.1422 - acc: 0.9486 - val_loss: 0.4818 - val_acc: 0.8697
#
# Epoch 00079: val_acc did not improve from 0.88000
# Epoch 80/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1361 - acc: 0.9517 - val_loss: 0.4416 - val_acc: 0.8809
#
# Epoch 00080: val_acc improved from 0.88000 to 0.88094, saving model to modelBest.h5
# Epoch 81/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.1405 - acc: 0.9498 - val_loss: 0.4169 - val_acc: 0.8812
#
# Epoch 00081: val_acc improved from 0.88094 to 0.88125, saving model to modelBest.h5
# Epoch 82/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1329 - acc: 0.9521 - val_loss: 0.4460 - val_acc: 0.8712
#
# Epoch 00082: val_acc did not improve from 0.88125
# Epoch 83/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1468 - acc: 0.9471 - val_loss: 0.3926 - val_acc: 0.8919
#
# Epoch 00083: val_acc improved from 0.88125 to 0.89187, saving model to modelBest.h5
# Epoch 84/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1390 - acc: 0.9510 - val_loss: 0.4995 - val_acc: 0.8681
#
# Epoch 00084: val_acc did not improve from 0.89187
# Epoch 85/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.1399 - acc: 0.9498 - val_loss: 0.4780 - val_acc: 0.8684
#
# Epoch 00085: val_acc did not improve from 0.89187
# Epoch 86/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.1533 - acc: 0.9455 - val_loss: 0.4986 - val_acc: 0.8534
#
# Epoch 00086: val_acc did not improve from 0.89187
# Epoch 87/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.1305 - acc: 0.9537 - val_loss: 0.4734 - val_acc: 0.8784
#
# Epoch 00087: val_acc did not improve from 0.89187
# Epoch 88/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1320 - acc: 0.9511 - val_loss: 0.4455 - val_acc: 0.8775
#
# Epoch 00088: val_acc did not improve from 0.89187
# Epoch 89/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1225 - acc: 0.9565 - val_loss: 0.4493 - val_acc: 0.8722
#
# Epoch 00089: val_acc did not improve from 0.89187
# Epoch 90/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1268 - acc: 0.9543 - val_loss: 0.4862 - val_acc: 0.8653
#
# Epoch 00090: val_acc did not improve from 0.89187
# Epoch 91/100
# 390/390 [==============================] - 54s 137ms/step - loss: 0.1240 - acc: 0.9566 - val_loss: 0.4744 - val_acc: 0.8778
#
# Epoch 00091: val_acc did not improve from 0.89187
# Epoch 92/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1268 - acc: 0.9542 - val_loss: 0.4554 - val_acc: 0.8650
#
# Epoch 00092: val_acc did not improve from 0.89187
# Epoch 93/100
# 390/390 [==============================] - 54s 138ms/step - loss: 0.1276 - acc: 0.9545 - val_loss: 0.4754 - val_acc: 0.8697
#
# Epoch 00093: val_acc did not improve from 0.89187
# Epoch 94/100
# 390/390 [==============================] - 54s 138ms/step - loss: 0.1299 - acc: 0.9532 - val_loss: 0.4539 - val_acc: 0.8813
#
# Epoch 00094: val_acc did not improve from 0.89187
# Epoch 95/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1179 - acc: 0.9571 - val_loss: 0.4623 - val_acc: 0.8762
#
# Epoch 00095: val_acc did not improve from 0.89187
# Epoch 96/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1298 - acc: 0.9539 - val_loss: 0.5103 - val_acc: 0.8669
#
# Epoch 00096: val_acc did not improve from 0.89187
# Epoch 97/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1189 - acc: 0.9572 - val_loss: 0.4187 - val_acc: 0.8825
#
# Epoch 00097: val_acc did not improve from 0.89187
# Epoch 98/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1209 - acc: 0.9561 - val_loss: 0.4363 - val_acc: 0.8829
#
# Epoch 00098: val_acc did not improve from 0.89187
# Epoch 99/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1149 - acc: 0.9593 - val_loss: 0.4238 - val_acc: 0.8900
#
# Epoch 00099: val_acc did not improve from 0.89187
# Epoch 100/100
# 390/390 [==============================] - 53s 137ms/step - loss: 0.1189 - acc: 0.9579 - val_loss: 0.4542 - val_acc: 0.8759
#
# Epoch 00100: val_acc did not improve from 0.89187
# Model took 5358.75 seconds to train
# Accuracy on test data is: 32.51

# %%
from google.colab import files
files.download('modelBest.h5')

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5c39f775-61f8-46a6-b03a-e97ac8a48f38" name="files[]" multiple disabled />
#      <output id="result-5c39f775-61f8-46a6-b03a-e97ac8a48f38">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving modelBest (1).h5 to modelBest (1).h5

# %%
from keras.models import load_model
modelBest = load_model("modelBest (1).h5")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0629 13:15:25.932941 139681073305472 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0629 13:15:25.957337 139681073305472 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0629 13:15:26.119903 139681073305472 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0629 13:15:26.121013 139681073305472 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0629 13:15:26.125114 139681073305472 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0629 13:15:26.847132 139681073305472 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0629 13:15:26.920460 139681073305472 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0629 13:15:27.038673 139681073305472 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0629 13:15:27.924930 139681073305472 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0629 13:15:28.032824 139681073305472 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
from keras.preprocessing import image
import keras.backend as K
import numpy as np
import cv2
import sys

# %%
''' 
test_index = 4
img = test_features[test_index]
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
'''

# %%
from keras.preprocessing.image import ImageDataGenerator

predgen = ImageDataGenerator(featurewise_center=True,
                            featurewise_std_normalization=True)

predgen.fit(test_features)

pred_generator = predgen.flow(test_features, test_labels,
  shuffle=False)

y_pred = modelBest.predict_generator(pred_generator, steps=1)

# %%
for test_index in range(10):
  print(test_index, np.argmax(y_pred[test_index]), np.argmax(test_labels[test_index]))
# Out:
# 0 3 3
# 1 8 8
# 2 8 8
# 3 0 0
# 4 6 6
# 5 6 6
# 6 1 1
# 7 6 6
# 8 3 3
# 9 8 1

# %%
#preds = modelBest.predict(x)
#print(preds)
#print(test_labels[test_index])

# %%
test_idx = 1
class_idx = np.argmax(y_pred[test_idx])
class_output = modelBest.output[:, class_idx]
last_conv_layer = modelBest.get_layer("activation_7")

# %%
grads = K.gradients(class_output, last_conv_layer.output)[0]
print(grads)
pooled_grads = K.mean(grads, axis=(0, 1, 2))
iterate = K.function([modelBest.input], [pooled_grads, last_conv_layer.output[0]])
x = test_features[test_idx]
x = np.expand_dims(x, axis=0)
pooled_grads_value, conv_layer_output_value = iterate([x])
for i in range(10):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
# Out:
# Tensor("gradients_17/AddN_1:0", shape=(?, 8, 8, 256), dtype=float32)

# %%
heatmap = np.mean(conv_layer_output_value, axis=-1)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)

# %%
from google.colab.patches import cv2_imshow
img = test_features[test_idx]
print(img.shape)
heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
heatmap = np.uint8(255 * heatmap)
img = np.uint8(255 * img)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)
cv2_imshow(img)
cv2_imshow(superimposed_img)
cv2.waitKey(0)
# Out:
# (32, 32, 3)
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F094B566C88>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F094B787518>
# -1

# %%
fig = plt.figure(figsize=(8,3))
plt.imshow(img)
plt.show()

# %%
fig = plt.figure(figsize=(8,3))
plt.imshow(superimposed_img)
plt.show()
