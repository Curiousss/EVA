# %% [markdown]
# <a href="https://colab.research.google.com/github/Curiousss/EVA/blob/master/Assignment6/Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step

# %%
print(train_features[0].shape)
print(num_classes)
# Out:
# (32, 32, 3)
# 10

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(64, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

#RF 3
#ip 30
model.add(Convolution2D(128, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

#RF 5
#ip 28
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(64, 1, 1, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

#RF 10
#ip 14
model.add(Convolution2D(128, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

# RF 12
# ip 12
model.add(Convolution2D(256, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

#RF 14
#ip 10
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(128, 1, 1, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

#RF 28
#ip 5
model.add(Convolution2D(256, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

#RF 30
# ip 3
model.add(Convolution2D(num_classes, 8, 8))
model.add(Flatten())
model.add(Activation('softmax'))
#RF 32

model.summary()

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (1, 1), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), padding="same")`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_43 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation_41 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 32, 32, 128)       73856
# _________________________________________________________________
# activation_42 (Activation)   (None, 32, 32, 128)       0
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 16, 16, 64)        8256
# _________________________________________________________________
# activation_43 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_44 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 16, 16, 256)       295168
# _________________________________________________________________
# activation_45 (Activation)   (None, 16, 16, 256)       0
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 16, 16, 256)       1024
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 8, 8, 128)         32896
# _________________________________________________________________
# activation_46 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_47 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 1, 1, 10)          163850
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_48 (Activation)   (None, 10)                0
# =================================================================
# Total params: 948,938
# Trainable params: 946,890
# Non-trainable params: 2,048
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:46: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:53: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8))`

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False,
                            featurewise_center=True,
                            featurewise_std_normalization=True)

testgen = ImageDataGenerator(featurewise_center=True,
                            featurewise_std_normalization=True)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = testgen.flow(test_features, test_labels), validation_steps=100, verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# Epoch 1/100
#   2/390 [..............................] - ETA: 37s - loss: 0.1035 - acc: 0.9648
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=<keras_pre..., validation_steps=100, verbose=1, steps_per_epoch=390, epochs=100)`
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:699: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:707: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0771 - acc: 0.9723 - val_loss: 0.7891 - val_acc: 0.8113
# Epoch 2/100
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0758 - acc: 0.9743 - val_loss: 0.6881 - val_acc: 0.8397
# Epoch 3/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0721 - acc: 0.9746 - val_loss: 0.7501 - val_acc: 0.8294
# Epoch 4/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0795 - acc: 0.9716 - val_loss: 0.7020 - val_acc: 0.8298
# Epoch 5/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0719 - acc: 0.9746 - val_loss: 0.6902 - val_acc: 0.8381
# Epoch 6/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0752 - acc: 0.9738 - val_loss: 0.7214 - val_acc: 0.8259
# Epoch 7/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0740 - acc: 0.9738 - val_loss: 0.6389 - val_acc: 0.8445
# Epoch 8/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0710 - acc: 0.9752 - val_loss: 0.6565 - val_acc: 0.8316
# Epoch 9/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0686 - acc: 0.9759 - val_loss: 0.6921 - val_acc: 0.8372
# Epoch 10/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0700 - acc: 0.9750 - val_loss: 0.7038 - val_acc: 0.8301
# Epoch 11/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0731 - acc: 0.9740 - val_loss: 0.7287 - val_acc: 0.8263
# Epoch 12/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0678 - acc: 0.9760 - val_loss: 0.7296 - val_acc: 0.8325
# Epoch 13/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0715 - acc: 0.9756 - val_loss: 0.7873 - val_acc: 0.8216
# Epoch 14/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0668 - acc: 0.9761 - val_loss: 0.6413 - val_acc: 0.8391
# Epoch 15/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0659 - acc: 0.9765 - val_loss: 0.6797 - val_acc: 0.8372
# Epoch 16/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0691 - acc: 0.9754 - val_loss: 0.6384 - val_acc: 0.8323
# Epoch 17/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0647 - acc: 0.9770 - val_loss: 0.6569 - val_acc: 0.8472
# Epoch 18/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0662 - acc: 0.9766 - val_loss: 0.6900 - val_acc: 0.8381
# Epoch 19/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0666 - acc: 0.9760 - val_loss: 0.7282 - val_acc: 0.8313
# Epoch 20/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0646 - acc: 0.9769 - val_loss: 0.6906 - val_acc: 0.8287
# Epoch 21/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0650 - acc: 0.9770 - val_loss: 0.6284 - val_acc: 0.8425
# Epoch 22/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0662 - acc: 0.9762 - val_loss: 0.7497 - val_acc: 0.8288
# Epoch 23/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0645 - acc: 0.9772 - val_loss: 0.7151 - val_acc: 0.8294
# Epoch 24/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0666 - acc: 0.9766 - val_loss: 0.7049 - val_acc: 0.8363
# Epoch 25/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0656 - acc: 0.9767 - val_loss: 0.7235 - val_acc: 0.8344
# Epoch 26/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0677 - acc: 0.9767 - val_loss: 0.6968 - val_acc: 0.8276
# Epoch 27/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0615 - acc: 0.9781 - val_loss: 0.7480 - val_acc: 0.8263
# Epoch 28/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0583 - acc: 0.9794 - val_loss: 0.7417 - val_acc: 0.8297
# Epoch 29/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0586 - acc: 0.9798 - val_loss: 0.7146 - val_acc: 0.8339
# Epoch 30/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0606 - acc: 0.9791 - val_loss: 0.7157 - val_acc: 0.8294
# Epoch 31/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0672 - acc: 0.9770 - val_loss: 0.7440 - val_acc: 0.8316
# Epoch 32/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0575 - acc: 0.9803 - val_loss: 0.6710 - val_acc: 0.8370
# Epoch 33/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0597 - acc: 0.9798 - val_loss: 0.6796 - val_acc: 0.8372
# Epoch 34/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0906 - acc: 0.9718 - val_loss: 0.7252 - val_acc: 0.8337
# Epoch 35/100
# 390/390 [==============================] - 29s 76ms/step - loss: 0.0682 - acc: 0.9761 - val_loss: 0.6821 - val_acc: 0.8411
# Epoch 36/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0625 - acc: 0.9778 - val_loss: 0.7400 - val_acc: 0.8375
# Epoch 37/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0577 - acc: 0.9802 - val_loss: 0.7829 - val_acc: 0.8153
# Epoch 38/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0592 - acc: 0.9791 - val_loss: 0.6945 - val_acc: 0.8392
# Epoch 39/100
# 390/390 [==============================] - 29s 76ms/step - loss: 0.0591 - acc: 0.9792 - val_loss: 0.6710 - val_acc: 0.8447
# Epoch 40/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0561 - acc: 0.9804 - val_loss: 0.7310 - val_acc: 0.8372
# Epoch 41/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0579 - acc: 0.9790 - val_loss: 0.7282 - val_acc: 0.8329
# Epoch 42/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0617 - acc: 0.9787 - val_loss: 0.6287 - val_acc: 0.8444
# Epoch 43/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0552 - acc: 0.9803 - val_loss: 0.7488 - val_acc: 0.8375
# Epoch 44/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0555 - acc: 0.9810 - val_loss: 0.8120 - val_acc: 0.8241
# Epoch 45/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0607 - acc: 0.9784 - val_loss: 0.7639 - val_acc: 0.8294
# Epoch 46/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0550 - acc: 0.9807 - val_loss: 0.7039 - val_acc: 0.8459
# Epoch 47/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0589 - acc: 0.9789 - val_loss: 0.6700 - val_acc: 0.8502
# Epoch 48/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0546 - acc: 0.9810 - val_loss: 0.8063 - val_acc: 0.8309
# Epoch 49/100
# 390/390 [==============================] - 29s 76ms/step - loss: 0.0544 - acc: 0.9813 - val_loss: 0.6866 - val_acc: 0.8350
# Epoch 50/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0538 - acc: 0.9809 - val_loss: 0.7661 - val_acc: 0.8303
# Epoch 51/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0578 - acc: 0.9797 - val_loss: 0.7030 - val_acc: 0.8420
# Epoch 52/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0537 - acc: 0.9804 - val_loss: 0.7048 - val_acc: 0.8472
# Epoch 53/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0547 - acc: 0.9810 - val_loss: 0.7112 - val_acc: 0.8266
# Epoch 54/100
# 390/390 [==============================] - 29s 76ms/step - loss: 0.0589 - acc: 0.9798 - val_loss: 0.7743 - val_acc: 0.8279
# Epoch 55/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0544 - acc: 0.9813 - val_loss: 0.8345 - val_acc: 0.8284
# Epoch 56/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0504 - acc: 0.9820 - val_loss: 0.6827 - val_acc: 0.8469
# Epoch 57/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0546 - acc: 0.9808 - val_loss: 0.7714 - val_acc: 0.8546
# Epoch 58/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0543 - acc: 0.9815 - val_loss: 0.8286 - val_acc: 0.8181
# Epoch 59/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0554 - acc: 0.9814 - val_loss: 0.8063 - val_acc: 0.8334
# Epoch 60/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0534 - acc: 0.9814 - val_loss: 0.7683 - val_acc: 0.8448
# Epoch 61/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0497 - acc: 0.9822 - val_loss: 0.8567 - val_acc: 0.8175
# Epoch 62/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0526 - acc: 0.9813 - val_loss: 0.7137 - val_acc: 0.8400
# Epoch 63/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0500 - acc: 0.9821 - val_loss: 0.7327 - val_acc: 0.8386
# Epoch 64/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0554 - acc: 0.9804 - val_loss: 0.8037 - val_acc: 0.8319
# Epoch 65/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0535 - acc: 0.9815 - val_loss: 0.9386 - val_acc: 0.8247
# Epoch 66/100
# 390/390 [==============================] - 29s 76ms/step - loss: 0.0547 - acc: 0.9812 - val_loss: 0.8029 - val_acc: 0.8307
# Epoch 67/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0523 - acc: 0.9816 - val_loss: 0.7721 - val_acc: 0.8391
# Epoch 68/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0504 - acc: 0.9823 - val_loss: 0.7803 - val_acc: 0.8344
# Epoch 69/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0515 - acc: 0.9825 - val_loss: 0.7344 - val_acc: 0.8430
# Epoch 70/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0479 - acc: 0.9838 - val_loss: 0.7625 - val_acc: 0.8384
# Epoch 71/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0520 - acc: 0.9823 - val_loss: 0.7977 - val_acc: 0.8250
# Epoch 72/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0501 - acc: 0.9826 - val_loss: 0.7705 - val_acc: 0.8354
# Epoch 73/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0516 - acc: 0.9828 - val_loss: 0.7473 - val_acc: 0.8444
# Epoch 74/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0525 - acc: 0.9821 - val_loss: 0.7380 - val_acc: 0.8419
# Epoch 75/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0503 - acc: 0.9824 - val_loss: 0.8392 - val_acc: 0.8419
# Epoch 76/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0483 - acc: 0.9831 - val_loss: 0.9560 - val_acc: 0.8204
# Epoch 77/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0504 - acc: 0.9822 - val_loss: 0.7423 - val_acc: 0.8428
# Epoch 78/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0479 - acc: 0.9838 - val_loss: 1.3078 - val_acc: 0.7981
# Epoch 79/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0480 - acc: 0.9840 - val_loss: 0.9787 - val_acc: 0.8156
# Epoch 80/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0486 - acc: 0.9832 - val_loss: 1.4117 - val_acc: 0.7981
# Epoch 81/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0468 - acc: 0.9831 - val_loss: 0.7602 - val_acc: 0.8384
# Epoch 82/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0505 - acc: 0.9828 - val_loss: 0.7867 - val_acc: 0.8398
# Epoch 83/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0478 - acc: 0.9830 - val_loss: 0.7269 - val_acc: 0.8434
# Epoch 84/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0483 - acc: 0.9833 - val_loss: 0.8095 - val_acc: 0.8309
# Epoch 85/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0458 - acc: 0.9842 - val_loss: 0.6952 - val_acc: 0.8533
# Epoch 86/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0450 - acc: 0.9845 - val_loss: 0.7094 - val_acc: 0.8516
# Epoch 87/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0499 - acc: 0.9832 - val_loss: 0.8771 - val_acc: 0.8187
# Epoch 88/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0480 - acc: 0.9834 - val_loss: 0.8250 - val_acc: 0.8282
# Epoch 89/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0442 - acc: 0.9844 - val_loss: 0.8277 - val_acc: 0.8325
# Epoch 90/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0411 - acc: 0.9851 - val_loss: 0.7903 - val_acc: 0.8425
# Epoch 91/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0476 - acc: 0.9836 - val_loss: 0.7483 - val_acc: 0.8474
# Epoch 92/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0446 - acc: 0.9848 - val_loss: 0.8101 - val_acc: 0.8366
# Epoch 93/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0474 - acc: 0.9840 - val_loss: 0.7870 - val_acc: 0.8384
# Epoch 94/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0428 - acc: 0.9852 - val_loss: 0.7422 - val_acc: 0.8489
# Epoch 95/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0448 - acc: 0.9844 - val_loss: 0.7306 - val_acc: 0.8419
# Epoch 96/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0424 - acc: 0.9859 - val_loss: 0.8089 - val_acc: 0.8300
# Epoch 97/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0468 - acc: 0.9836 - val_loss: 0.7603 - val_acc: 0.8538
# Epoch 98/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0446 - acc: 0.9844 - val_loss: 0.7333 - val_acc: 0.8379
# Epoch 99/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0438 - acc: 0.9855 - val_loss: 0.7596 - val_acc: 0.8431
# Epoch 100/100
# 390/390 [==============================] - 29s 75ms/step - loss: 0.0431 - acc: 0.9848 - val_loss: 0.8917 - val_acc: 0.8141
# Model took 2934.97 seconds to train
# Accuracy on test data is: 82.00
